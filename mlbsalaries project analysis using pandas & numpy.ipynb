# %% [markdown]
# # mlbsalaries :- Major League Baseball Salaries Dataset

# %%
import pandas as pd 
import numpy as np

# %%
# read data first
mlbsalaries_data = pd.read_csv('dataset/mlbsalaries.csv')
mlbsalaries_data
# Out:
#        Year           Player   Salary           Position                Team
# 0      1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1      1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2      1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3      1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4      1988        Bob Boone   883000            Catcher  Los Angeles Angels
# ...     ...              ...      ...                ...                 ...
# 19538  2011   Gustavo Molina   455000            Catcher    New York Yankees
# 19539  2011        Ivan Nova   432900            Pitcher    New York Yankees
# 19540  2011     Colin Curtis   420400         Outfielder    New York Yankees
# 19541  2011    Eduardo Nunez   419300          Shortstop    New York Yankees
# 19542  2011    Reegie Corona   414000     Second Baseman    New York Yankees
#
# [19543 rows x 5 columns]

# %%
mlbsalaries_data.shape
# Out:
# (19543, 5)

# %%
mlbsalaries_data.columns
# Out:
# Index(['Year', 'Player', 'Salary', 'Position', 'Team'], dtype='object')

# %%
mlbsalaries_data.describe
# Out:
# <bound method NDFrame.describe of        Year           Player   Salary           Position                Team
# 0      1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1      1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2      1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3      1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4      1988        Bob Boone   883000            Catcher  Los Angeles Angels
# ...     ...              ...      ...                ...                 ...
# 19538  2011   Gustavo Molina   455000            Catcher    New York Yankees
# 19539  2011        Ivan Nova   432900            Pitcher    New York Yankees
# 19540  2011     Colin Curtis   420400         Outfielder    New York Yankees
# 19541  2011    Eduardo Nunez   419300          Shortstop    New York Yankees
# 19542  2011    Reegie Corona   414000     Second Baseman    New York Yankees
#
# ...

# %%
mlbsalaries_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19543 entries, 0 to 19542
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      19543 non-null  int64
#  1   Player    19543 non-null  object
#  2   Salary    19543 non-null  int64
#  3   Position  19543 non-null  object
#  4   Team      19543 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 763.5+ KB

# %%
mlbsalaries_data.dtypes
# Out:
# Year         int64
# Player      object
# Salary       int64
# Position    object
# Team        object
# dtype: object

# %%
mlbsalaries_data.head()
# Out:
#    Year           Player   Salary           Position                Team
# 0  1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1  1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2  1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3  1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4  1988        Bob Boone   883000            Catcher  Los Angeles Angels

# %%
mlbsalaries_data.tail()
# Out:
#        Year          Player  Salary        Position              Team
# 19538  2011  Gustavo Molina  455000         Catcher  New York Yankees
# 19539  2011       Ivan Nova  432900         Pitcher  New York Yankees
# 19540  2011    Colin Curtis  420400      Outfielder  New York Yankees
# 19541  2011   Eduardo Nunez  419300       Shortstop  New York Yankees
# 19542  2011   Reegie Corona  414000  Second Baseman  New York Yankees

# %%
mlbsalaries_data.Year.value_counts() # number of record in one year
# Out:
# Year
# 1990    972
# 1999    919
# 2008    858
# 2001    857
# 2002    849
# 2007    848
# 1998    846
# 2000    843
# 2011    843
# 2004    833
# 2005    831
# 2010    828
# 2003    826
# 2006    823
# 2009    818
# 1995    805
# 1993    786
# 1997    773
# 1996    768
# 1992    753
# 1994    748
# 1991    720
# 1989    710
# 1988    686
# Name: count, dtype: int64

# %% [markdown]
# # 1. How to find out total no. of records

# %%
mlbsalaries_data.shape[0]
# Out:
# 19543

# %% [markdown]
# # 2. How to find out total no. of columns?

# %%
mlbsalaries_data.shape[1]
# Out:
# 5

# %% [markdown]
# # 3. Display all column names ?

# %%
mlbsalaries_data.columns
# Out:
# Index(['Year', 'Player', 'Salary', 'Position', 'Team'], dtype='object')

# %% [markdown]
# # 4. Show only maximum salary value?

# %%
max_salary = mlbsalaries_data['Salary'].max()
print(max_salary)
# Out:
# 33000000

# %% [markdown]
# # 5. Show only mininum salary value?

# %%
minimum_salary = mlbsalaries_data['Salary'].min()
print(minimum_salary)
# Out:
# 62500

# %% [markdown]
# # 6. Show Maximum salary complete record?

# %%
maximum_salary_record = mlbsalaries_data.loc[mlbsalaries_data['Salary'].idxmax()]
print(maximum_salary_record)
# Out:
# Year                    2009
# Player        Alex Rodriguez
# Salary              33000000
# Position       Third Baseman
# Team        New York Yankees
# Name: 17846, dtype: object

# %%
mlbsalaries_data.sort_values('Salary',ascending=False)[:1]
# Out:
#        Year          Player    Salary       Position              Team
# 17846  2009  Alex Rodriguez  33000000  Third Baseman  New York Yankees

# %% [markdown]
# # 7. Show Minimum salary complete record?

# %%
minimum_salary_record = mlbsalaries_data.loc[mlbsalaries_data['Salary'].idxmin()]
print(minimum_salary_record)
# Out:
# Year                      1988
# Player             Thad Bosley
# Salary                   62500
# Position            Outfielder
# Team        Los Angeles Angels
# Name: 21, dtype: object

# %%
mlbsalaries_data.sort_values('Salary',ascending=True)[:1]
# Out:
#     Year        Player  Salary Position                Team
# 25  1988  Bryan Harvey   62500  Pitcher  Los Angeles Angels

# %% [markdown]
# # 8. Show all records Team Wise Details?

# %%
# Group the data by the 'Team' column and display the details    ######
team_wise_details = mlbsalaries_data.Team.value_counts()

print(team_wise_details)
# Out:
# Team
# Texas Rangers            711
# Los Angeles Dodgers      698
# Philadelphia Phillies    695
# Los Angeles Angels       695
# St. Louis Cardinals      693
# Cleveland Indians        693
# Boston Red Sox           692
# Milwaukee Brewers        690
# Washington Nationals     687
# New York Yankees         685
# Seattle Mariners         684
# Baltimore Orioles        684
# Toronto Blue Jays        683
# Atlanta Braves           683
# Cincinnati Reds          681
# San Francisco Giants     678
# Detroit Tigers           676
# New York Mets            676
# Oakland Athletics        674
# Kansas City Royals       674
# San Diego Padres         673
# Pittsburgh Pirates       669
# Chicago Cubs             663
# Houston Astros           660
# Minnesota Twins          650
# Chicago White Sox        648
# Florida Marlins          533
# Colorado Rockies         528
# Tampa Bay Rays           398
# Arizona Diamondbacks     389
# Name: count, dtype: int64

# %%
m = mlbsalaries_data.groupby('Team')
m

# %%
for Team, data in m:
    print('Team:',Team)
    print('\n')
    print('data:',data)
# Out:
# Team: Arizona Diamondbacks
#
#
# data:        Year            Player   Salary       Position                  Team
# 7951   1998        Andy Benes  6000000        Pitcher  Arizona Diamondbacks
# 7952   1998          Jay Bell  5000000      Shortstop  Arizona Diamondbacks
# 7953   1998  Matt D. Williams  4500000  Third Baseman  Arizona Diamondbacks
# 7954   1998       Devon White  3500000     Outfielder  Arizona Diamondbacks
# 7955   1998      Willie Blair  3250000        Pitcher  Arizona Diamondbacks
# ...     ...               ...      ...            ...                   ...
# 18949  2011        Dan Hudson   419000        Pitcher  Arizona Diamondbacks
# 18950  2011     Barry Enright   418000        Pitcher  Arizona Diamondbacks
# 18951  2011      Samuel Demel   417000        Pitcher  Arizona Diamondbacks
# 18952  2011      Kam Mickolio   417000        Pitcher  Arizona Diamondbacks
# 18953  2011      Joe Paterson   414000        Pitcher  Arizona Diamondbacks
#
# ...

# %% [markdown]
# # 9. Show all records Year Wise Details?

# %%
mlbsalaries_data.Year.value_counts()
# Out:
# Year
# 1990    972
# 1999    919
# 2008    858
# 2001    857
# 2002    849
# 2007    848
# 1998    846
# 2000    843
# 2011    843
# 2004    833
# 2005    831
# 2010    828
# 2003    826
# 2006    823
# 2009    818
# 1995    805
# 1993    786
# 1997    773
# 1996    768
# 1992    753
# 1994    748
# 1991    720
# 1989    710
# 1988    686
# Name: count, dtype: int64

# %% [markdown]
# # 10. Show all player names which position=Pitcher?

# %%
mlbsalaries_data[mlbsalaries_data.Position == 'Pitcher' ]
# Out:
#        Year           Player   Salary Position                Team
# 0      1988        Mike Witt  1400000  Pitcher  Los Angeles Angels
# 6      1988        Dan Petry   785000  Pitcher  Los Angeles Angels
# 9      1988      Greg Minton   525000  Pitcher  Los Angeles Angels
# 12     1988   Kirk McCaskill   262000  Pitcher  Los Angeles Angels
# 15     1988    Willie Fraser   125000  Pitcher  Los Angeles Angels
# ...     ...              ...      ...      ...                 ...
# 19532  2011      Boone Logan  1200000  Pitcher    New York Yankees
# 19533  2011    Bartolo Colon   900000  Pitcher    New York Yankees
# 19534  2011       Luis Ayala   650000  Pitcher    New York Yankees
# 19536  2011  David Robertson   460450  Pitcher    New York Yankees
# 19539  2011        Ivan Nova   432900  Pitcher    New York Yankees
#
# [9160 rows x 5 columns]

# %% [markdown]
# # 11. How to find out all missing values count in all columns?

# %%
mlbsalaries_data.isnull().sum()
# Out:
# Year        0
# Player      0
# Salary      0
# Position    0
# Team        0
# dtype: int64

# %% [markdown]
# # 12. Show Team wise Salaries Total?

# %%
mlbsalaries_data.groupby('Team')['Salary'].sum()
# Out:
# Team
# Arizona Diamondbacks      946201895
# Atlanta Braves           1542085753
# Baltimore Orioles        1298762402
# Boston Red Sox           1930916542
# Chicago Cubs             1553704710
# Chicago White Sox        1345835356
# Cincinnati Reds          1096955520
# Cleveland Indians        1131273056
# Colorado Rockies         1024537935
# Detroit Tigers           1299947476
# Florida Marlins           655397557
# Houston Astros           1255881249
# Kansas City Royals        902090903
# Los Angeles Angels       1451520771
# Los Angeles Dodgers      1639707332
# Milwaukee Brewers         969994869
# Minnesota Twins           975014771
# New York Mets            1750206095
# New York Yankees         2599882202
# Oakland Athletics         950914242
# Philadelphia Phillies    1407873063
# Pittsburgh Pirates        734547656
# San Diego Padres          937123511
# San Francisco Giants     1382126239
# Seattle Mariners         1391042325
# St. Louis Cardinals      1404586805
# ...

# %%
m.Salary.sum()
# Out:
# Team
# Arizona Diamondbacks      946201895
# Atlanta Braves           1542085753
# Baltimore Orioles        1298762402
# Boston Red Sox           1930916542
# Chicago Cubs             1553704710
# Chicago White Sox        1345835356
# Cincinnati Reds          1096955520
# Cleveland Indians        1131273056
# Colorado Rockies         1024537935
# Detroit Tigers           1299947476
# Florida Marlins           655397557
# Houston Astros           1255881249
# Kansas City Royals        902090903
# Los Angeles Angels       1451520771
# Los Angeles Dodgers      1639707332
# Milwaukee Brewers         969994869
# Minnesota Twins           975014771
# New York Mets            1750206095
# New York Yankees         2599882202
# Oakland Athletics         950914242
# Philadelphia Phillies    1407873063
# Pittsburgh Pirates        734547656
# San Diego Padres          937123511
# San Francisco Giants     1382126239
# Seattle Mariners         1391042325
# St. Louis Cardinals      1404586805
# ...

# %% [markdown]
# # 13. Count All Players Team wise ?

# %%
mlbsalaries_data.groupby('Team')['Player'].count()
# Out:
# Team
# Arizona Diamondbacks     389
# Atlanta Braves           683
# Baltimore Orioles        684
# Boston Red Sox           692
# Chicago Cubs             663
# Chicago White Sox        648
# Cincinnati Reds          681
# Cleveland Indians        693
# Colorado Rockies         528
# Detroit Tigers           676
# Florida Marlins          533
# Houston Astros           660
# Kansas City Royals       674
# Los Angeles Angels       695
# Los Angeles Dodgers      698
# Milwaukee Brewers        690
# Minnesota Twins          650
# New York Mets            676
# New York Yankees         685
# Oakland Athletics        674
# Philadelphia Phillies    695
# Pittsburgh Pirates       669
# San Diego Padres         673
# San Francisco Giants     678
# Seattle Mariners         684
# St. Louis Cardinals      693
# Tampa Bay Rays           398
# Texas Rangers            711
# Toronto Blue Jays        683
# Washington Nationals     687
# Name: Player, dtype: int64

# %%
m.Player.count()
# Out:
# Team
# Arizona Diamondbacks     389
# Atlanta Braves           683
# Baltimore Orioles        684
# Boston Red Sox           692
# Chicago Cubs             663
# Chicago White Sox        648
# Cincinnati Reds          681
# Cleveland Indians        693
# Colorado Rockies         528
# Detroit Tigers           676
# Florida Marlins          533
# Houston Astros           660
# Kansas City Royals       674
# Los Angeles Angels       695
# Los Angeles Dodgers      698
# Milwaukee Brewers        690
# Minnesota Twins          650
# New York Mets            676
# New York Yankees         685
# Oakland Athletics        674
# Philadelphia Phillies    695
# Pittsburgh Pirates       669
# San Diego Padres         673
# San Francisco Giants     678
# Seattle Mariners         684
# St. Louis Cardinals      693
# Tampa Bay Rays           398
# Texas Rangers            711
# Toronto Blue Jays        683
# Washington Nationals     687
# Name: Player, dtype: int64

# %% [markdown]
# # 14. Show all unique Team names?

# %%
mlbsalaries_data['Team'].unique()
# Out:
# array(['Los Angeles Angels', 'Houston Astros', 'Oakland Athletics',
#        'Toronto Blue Jays', 'Atlanta Braves', 'Milwaukee Brewers',
#        'St. Louis Cardinals', 'Chicago Cubs', 'Los Angeles Dodgers',
#        'San Francisco Giants', 'Cleveland Indians', 'Seattle Mariners',
#        'New York Mets', 'Washington Nationals', 'Baltimore Orioles',
#        'San Diego Padres', 'Philadelphia Phillies', 'Pittsburgh Pirates',
#        'Texas Rangers', 'Cincinnati Reds', 'Boston Red Sox',
#        'Kansas City Royals', 'Detroit Tigers', 'Minnesota Twins',
#        'Chicago White Sox', 'New York Yankees', 'Florida Marlins',
#        'Colorado Rockies', 'Arizona Diamondbacks', 'Tampa Bay Rays'],
#       dtype=object)

# %% [markdown]
# # 15. Display Total no. of Unique Teams?

# %%
mlbsalaries_data['Team'].nunique()
# Out:
# 30

# %% [markdown]
# # 16. How to find out year wise total count?

# %%
mlbsalaries_data.groupby('Year').count()
# Out:
#       Player  Salary  Position  Team
# Year
# 1988     686     686       686   686
# 1989     710     710       710   710
# 1990     972     972       972   972
# 1991     720     720       720   720
# 1992     753     753       753   753
# 1993     786     786       786   786
# 1994     748     748       748   748
# 1995     805     805       805   805
# 1996     768     768       768   768
# 1997     773     773       773   773
# 1998     846     846       846   846
# 1999     919     919       919   919
# 2000     843     843       843   843
# 2001     857     857       857   857
# 2002     849     849       849   849
# 2003     826     826       826   826
# 2004     833     833       833   833
# 2005     831     831       831   831
# 2006     823     823       823   823
# 2007     848     848       848   848
# 2008     858     858       858   858
# 2009     818     818       818   818
# 2010     828     828       828   828
# 2011     843     843       843   843

# %% [markdown]
# # 17. How to find out Team wise total count?

# %%
mlbsalaries_data.groupby('Team').count()
# Out:
#                        Year  Player  Salary  Position
# Team
# Arizona Diamondbacks    389     389     389       389
# Atlanta Braves          683     683     683       683
# Baltimore Orioles       684     684     684       684
# Boston Red Sox          692     692     692       692
# Chicago Cubs            663     663     663       663
# Chicago White Sox       648     648     648       648
# Cincinnati Reds         681     681     681       681
# Cleveland Indians       693     693     693       693
# Colorado Rockies        528     528     528       528
# Detroit Tigers          676     676     676       676
# Florida Marlins         533     533     533       533
# Houston Astros          660     660     660       660
# Kansas City Royals      674     674     674       674
# Los Angeles Angels      695     695     695       695
# Los Angeles Dodgers     698     698     698       698
# Milwaukee Brewers       690     690     690       690
# ...

# %% [markdown]
# # 18. How to find out Position wise total count?

# %%
mlbsalaries_data.groupby('Position').count()
# Out:
#                    Year  Player  Salary  Team
# Position
# Catcher            1664    1664    1664  1664
# Designated Hitter   109     109     109   109
# First Baseman      1118    1118    1118  1118
# Infielder            21      21      21    21
# Outfielder         3785    3785    3785  3785
# Pitcher            9160    9160    9160  9160
# Second Baseman     1216    1216    1216  1216
# Shortstop          1331    1331    1331  1331
# Third Baseman      1139    1139    1139  1139

# %% [markdown]
# # 19. Show all records for the year 2010 & also count how many records?

# %%
records_2010 = mlbsalaries_data[mlbsalaries_data['Year']== 2010]

print(records_2010)

number_of_record = records_2010.shape
print(number_of_record)
# Out:
#        Year              Player    Salary    Position                Team
# 17872  2010        Torii Hunter  18500000  Outfielder  Los Angeles Angels
# 17873  2010         Bobby Abreu   9000000  Outfielder  Los Angeles Angels
# 17874  2010       Brian Fuentes   9000000     Pitcher  Los Angeles Angels
# 17875  2010        Scott Kazmir   8000000     Pitcher  Los Angeles Angels
# 17876  2010        Joel Pineiro   8000000     Pitcher  Los Angeles Angels
# ...     ...                 ...       ...         ...                 ...
# 18695  2010         Phil Hughes    447000     Pitcher    New York Yankees
# 18696  2010      Alfredo Aceves    435650     Pitcher    New York Yankees
# 18697  2010     David Robertson    426650     Pitcher    New York Yankees
# 18698  2010         Ramiro Pena    412100   Infielder    New York Yankees
# 18699  2010  Francisco Cervelli    410800     Catcher    New York Yankees
#
# [828 rows x 5 columns]
# (828, 5)

# %% [markdown]
# # 20. How to Sort records by player in ascending order for the year 2010?

# %%
records_2010 = mlbsalaries_data[mlbsalaries_data['Year'] == 2010]

sorted_records_2010 = records_2010.sort_values(by='Player', ascending=True)

print(sorted_records_2010)
# Out:
#        Year                     Player    Salary   Position  \
# 18679  2010               A.J. Burnett  16500000    Pitcher
# 18655  2010            A.J. Pierzynski   6750000    Catcher
# 18540  2010                 Aaron Cook   9625000    Pitcher
# 18484  2010               Aaron Harang  12500000    Pitcher
# 18108  2010              Aaron Heilman   2150000    Pitcher
# ...     ...                        ...       ...        ...
# 18008  2010              Yunel Escobar    435000  Shortstop
# 18572  2010  Yuniesky Betancourt-Perez   3300000  Shortstop
# 18403  2010                  Zach Duke   4300000    Pitcher
# 18610  2010                 Zach Miner    950000    Pitcher
# 18569  2010               Zack Greinke   7250000    Pitcher
#
#                        Team
# 18679      New York Yankees
# 18655     Chicago White Sox
# 18540      Colorado Rockies
# 18484       Cincinnati Reds
# 18108  Arizona Diamondbacks
# ...                     ...
# 18008        Atlanta Braves
# ...

# %% [markdown]
# # 21. How to Sort column labels in ascending order for the year 2010?

# %%
data = mlbsalaries_data[mlbsalaries_data.Year == 2010]
data1 = sorted(mlbsalaries_data.columns)
data2 = data.reindex(columns=data1)
data2
# Out:
#                    Player    Position    Salary                Team  Year
# 17872        Torii Hunter  Outfielder  18500000  Los Angeles Angels  2010
# 17873         Bobby Abreu  Outfielder   9000000  Los Angeles Angels  2010
# 17874       Brian Fuentes     Pitcher   9000000  Los Angeles Angels  2010
# 17875        Scott Kazmir     Pitcher   8000000  Los Angeles Angels  2010
# 17876        Joel Pineiro     Pitcher   8000000  Los Angeles Angels  2010
# ...                   ...         ...       ...                 ...   ...
# 18695         Phil Hughes     Pitcher    447000    New York Yankees  2010
# 18696      Alfredo Aceves     Pitcher    435650    New York Yankees  2010
# 18697     David Robertson     Pitcher    426650    New York Yankees  2010
# 18698         Ramiro Pena   Infielder    412100    New York Yankees  2010
# 18699  Francisco Cervelli     Catcher    410800    New York Yankees  2010
#
# [828 rows x 5 columns]

# %% [markdown]
# # 22. How to find out Top 5 highest paid salary records for the year 2010?    [show only 2 columns: Player name & Salary]

# %%
mlbsalaries_data.Salary.sort_values(ascending=False).head()
# Out:
# 17846    33000000
# 18675    33000000
# 19513    32000000
# 17023    28000000
# 18700    26187500
# Name: Salary, dtype: int64

# %%
mlbsalaries_data.loc[mlbsalaries_data.Salary.sort_values(ascending=False).index[:5],['Player','Salary']]
# Out:
#                Player    Salary
# 17846  Alex Rodriguez  33000000
# 18675  Alex Rodriguez  33000000
# 19513  Alex Rodriguez  32000000
# 17023  Alex Rodriguez  28000000
# 18700    Vernon Wells  26187500

# %%
# 09 nov
